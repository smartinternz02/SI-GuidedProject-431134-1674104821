# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('Enhanced_Mining_dataset.csv')

# %%
data=data.drop(columns=["date"])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 346475 entries, 0 to 346474
# Data columns (total 7 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   avg_air_flow_267      346475 non-null  float64
#  1   avg_float_level_47    346475 non-null  float64
#  2   % Iron Feed           346475 non-null  float64
#  3   Amina Flow            346475 non-null  float64
#  4   Ore Pulp pH           346475 non-null  float64
#  5   Ore Pulp Density      346475 non-null  float64
#  6   % Silica Concentrate  346475 non-null  float64
# dtypes: float64(7)
# memory usage: 18.5 MB

# %%
for cols in data.columns.tolist()[1:]:
    df=data.loc[data[cols]>0]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 346475 entries, 0 to 346474
# Data columns (total 7 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   avg_air_flow_267      346475 non-null  float64
#  1   avg_float_level_47    346475 non-null  float64
#  2   % Iron Feed           346475 non-null  float64
#  3   Amina Flow            346475 non-null  float64
#  4   Ore Pulp pH           346475 non-null  float64
#  5   Ore Pulp Density      346475 non-null  float64
#  6   % Silica Concentrate  346475 non-null  float64
# dtypes: float64(7)
# memory usage: 21.1 MB

# %%
data.describe()
# Out:
#        avg_air_flow_267  avg_float_level_47    % Iron Feed     Amina Flow  \
# count     346475.000000       346475.000000  346475.000000  346475.000000
# mean         287.510395          421.699312      57.263148     503.008602
# std           19.247813           64.908753       5.124180      68.070518
# min          236.065667          244.894000      46.760000     305.720000
# 25%          282.396167          360.941000      53.200000     454.100500
# 50%          297.783000          414.785500      56.650000     511.047000
# 75%          300.449000          479.116750      64.030000     553.664000
# max          342.104333          596.743500      65.780000     670.561000
#
#          Ore Pulp pH  Ore Pulp Density  % Silica Concentrate
# count  346475.000000     346475.000000         346475.000000
# mean        9.846648          1.694629              2.060390
# std         0.305524          0.051392              0.878811
# min         8.993670          1.541890              0.600000
# 25%         9.636070          1.663966              1.370000
# 50%         9.865610          1.701810              1.810000
# 75%        10.072000          1.731100              2.550000
# max        10.541604          1.818810              4.577587

# %%
import matplotlib.pyplot as plt
from matplotlib import style
df.hist(bins = 70, figsize = (17,15))
plt.show()
plt.suptitle('figure title', color='w')
# Out:
# Text(0.5, 0.98, 'figure title')

# %%
data.isnull()
# Out:
#         avg_air_flow_267  avg_float_level_47  % Iron Feed  Amina Flow  \
# 0                  False               False        False       False
# 1                  False               False        False       False
# 2                  False               False        False       False
# 3                  False               False        False       False
# 4                  False               False        False       False
# ...                  ...                 ...          ...         ...
# 346470             False               False        False       False
# 346471             False               False        False       False
# 346472             False               False        False       False
# 346473             False               False        False       False
# 346474             False               False        False       False
#
#         Ore Pulp pH  Ore Pulp Density  % Silica Concentrate
# 0             False             False                 False
# 1             False             False                 False
# 2             False             False                 False
# 3             False             False                 False
# 4             False             False                 False
# ...             ...               ...                   ...
# 346470        False             False                 False
# 346471        False             False                 False
# 346472        False             False                 False
# 346473        False             False                 False
# 346474        False             False                 False
#
# [346475 rows x 7 columns]

# %%
data.isnull().sum()
# Out:
# avg_air_flow_267        0
# avg_float_level_47      0
# % Iron Feed             0
# Amina Flow              0
# Ore Pulp pH             0
# Ore Pulp Density        0
# % Silica Concentrate    0
# dtype: int64

# %%
data.head(10)
# Out:
#    avg_air_flow_267  avg_float_level_47  % Iron Feed  Amina Flow  Ore Pulp pH  \
# 0        251.448000            483.4510         55.2     557.434      10.0664
# 1        249.887667            473.0805         55.2     563.965      10.0672
# 2        249.096667            454.1275         55.2     568.054      10.0680
# 3        252.018667            436.9395         55.2     568.665      10.0689
# 4        250.349000            439.6745         55.2     558.167      10.0697
# 5        250.378333            432.6890         55.2     564.697      10.0705
# 6        252.209667            431.2895         55.2     566.467      10.0713
# 7        252.143667            445.8730         55.2     558.777      10.0722
# 8        250.188333            455.4945         55.2     556.030      10.0730
# 9        249.616667            456.4875         55.2     565.857      10.0738
#
#    Ore Pulp Density  % Silica Concentrate
# 0              1.74                  1.31
# 1              1.74                  1.31
# 2              1.74                  1.31
# 3              1.74                  1.31
# 4              1.74                  1.31
# 5              1.74                  1.31
# 6              1.74                  1.31
# 7              1.74                  1.31
# 8              1.74                  1.31
# 9              1.74                  1.31

# %%
data.hist(bins=50,figsize=(18,18))
# Out:
# array([[<AxesSubplot:title={'center':'avg_air_flow_267'}>,
#         <AxesSubplot:title={'center':'avg_float_level_47'}>,
#         <AxesSubplot:title={'center':'% Iron Feed'}>],
#        [<AxesSubplot:title={'center':'Amina Flow'}>,
#         <AxesSubplot:title={'center':'Ore Pulp pH'}>,
#         <AxesSubplot:title={'center':'Ore Pulp Density'}>],
#        [<AxesSubplot:title={'center':'% Silica Concentrate'}>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
x=data.iloc[:,:-1].values
y=data.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=10)

# %%
X_train
# Out:
# array([[303.04766667, 449.704     ,  49.85      , 557.714     ,
#           9.89813   ,   1.67719   ],
#        [267.64933333, 547.582     ,  48.81      , 383.206     ,
#          10.225     ,   1.70944   ],
#        [301.698     , 343.0845    ,  47.05      , 434.788     ,
#          10.3392    ,   1.68191   ],
#        ...,
#        [284.334     , 329.078     ,  52.61      , 514.196     ,
#           9.70472   ,   1.69846   ],
#        [305.934     , 495.9195    ,  57.47      , 503.149     ,
#          10.1694    ,   1.66212   ],
#        [298.89833333, 454.856     ,  54.63      , 581.829     ,
#           9.78383   ,   1.64188   ]])

# %%
X_test
# Out:
# array([[299.949     , 501.8105    ,  64.03      , 419.018     ,
#           9.85956   ,   1.72714   ],
#        [301.46833333, 482.6445    ,  53.79      , 537.114     ,
#           9.70503   ,   1.73242   ],
#        [284.24233333, 350.8785    ,  56.65      , 439.317     ,
#          10.0146    ,   1.62641   ],
#        ...,
#        [282.95666667, 336.052     ,  56.65      , 532.266     ,
#          10.0442    ,   1.73352   ],
#        [296.01433333, 396.1225    ,  49.69      , 563.09      ,
#           9.28619   ,   1.74464   ],
#        [248.96833333, 508.014     ,  58.54      , 538.483     ,
#           9.51999   ,   1.71543   ]])

# %%
y_train
# Out:
# array([3.14, 1.88, 1.23, ..., 3.77, 1.14, 2.3 ])

# %%
y_test
# Out:
# array([1.  , 1.  , 2.37, ..., 3.48, 1.33, 1.41])

# %%
from sklearn.ensemble import RandomForestRegressor
reg_rf=RandomForestRegressor(n_estimators=10,random_state=0)
reg_rf.fit(X_train,y_train)
y_pred=reg_rf.predict(X_test)

# %%
from sklearn import metrics
print('MAE:',metrics.mean_absolute_error(y_test,y_pred))
print('MSE:',metrics.mean_squared_error(y_test,y_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# MAE: 0.11815908673599426
# MSE: 0.07343256207571833
# RMSE: 0.2709844314268226

# %%
metrics.r2_score(y_test,y_pred)
# Out:
# 0.9047745510761016

# %%
import pickle
pickle.dump(reg_rf,open('mining.pkl','wb'))
